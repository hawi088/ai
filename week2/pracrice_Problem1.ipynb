# %%
import pandas as pd
import numpy as np
print("Library imported")
# Out:
# Library imported

# %%
data = {
    "Name":['Nusin','Fenet' , 'Afran','Sifen','Raphael','Solane','Maranata','Olifen','Iyad','Ihan'],
    "Age":[5,5,6,5,6,6,5,5,7,5],
    "Math_Score":[80,90,97,91,80,100,60,50,99,95],
    "English_Score":[85,81,99,88,83,91,93,99,80,94],
    "Science_Score":[88,79,95,96,97,98,99,100,80,81]
}
df = pd.DataFrame(data)
print(df.head())
# Out:
#       Name  Age  Math_Score  English_Score  Science_Score
# 0    Nusin    5          80             85             88
# 1    Fenet    5          90             81             79
# 2    Afran    6          97             99             95
# 3    Sifen    5          91             88             96
# 4  Raphael    6          80             83             97

# %%
print(df['Science_Score'].mean())
# Out:
# 91.3

# %%
print(df['Math_Score'].mean())
# Out:
# 84.2

# %%
print(df['English_Score'].mean())
# Out:
# 89.3

# %%
max_score = df['Math_Score'].max()
top_student = df[df['Math_Score'] == max_score]
print(top_student)
# Out:
#      Name  Age  Math_Score  English_Score  Science_Score
# 5  Solane    6         100             91             98

# %%
solane_row =df[df['Name'] == 'Solane']

# %%
solane_Average = solane_row[['Math_Score','English_Score','Science_Score']].mean(axis=1).values[0]
print(solane_Average)
# Out:
# 96.33333333333333

# %%
df['Average'] = df[['Math_Score','English_Score','Science_Score']].mean(axis=1)
df.head()
# Out:
#       Name  Age  Math_Score  English_Score  Science_Score    Average
# 0    Nusin    5          80             85             88  84.333333
# 1    Fenet    5          90             81             79  83.333333
# 2    Afran    6          97             99             95  97.000000
# 3    Sifen    5          91             88             96  91.666667
# 4  Raphael    6          80             83             97  86.666667
